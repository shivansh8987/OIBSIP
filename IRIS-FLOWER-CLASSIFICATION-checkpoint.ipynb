# %% [markdown]
# # About Project
#
# the data set is about the measurements of Iris flower species.
# The data set consists of 50 samples from each of three species of Iris (Iris Setosa, Iris virginica, and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.

# %% [markdown]
# ## Problem Statement
# Classify Iris flower into different species based on their sepal and petal measurements.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing Data
# let's import the data set from csv file by importing file into pandas dataframe

# %%
df = pd.read_csv('IRIS.csv')
df.head() #head function is used to get top 5 rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail() #head function is used to get last 5 rows
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# ### Let's do some EDA with Data set to know more about set

# %%
df.shape #shape function will give us the rows & columns of dataset
# Out:
# (150, 5)

# %%
df.info() #info function will give us info of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Missing Data

# %%
df.isnull().sum() #isnull used to find null values in dataset
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.duplicated().sum() #checking the duplicate values in dataset
# Out:
# 3

# %% [markdown]
# # Get to know

# %% [markdown]
# so here we get to know that there is 150rows & 5 columns in data and only species column have the text values
# and in data there is no null values and we get 3 duplicates in the data

# %% [markdown]
# # Data Preprocessing

# %%
df.drop_duplicates(inplace=True)  #now we are droping the duplicate values
df.shape
# Out:
# (147, 5)

# %% [markdown]
# Changing categorical column 'Species' into numerical

# %%
df['species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: species, dtype: int64

# %%
#Coverting categorical columns coz ML modle will understand numerical values better
df['species'] = df['species'].replace({'Iris-versicolor':0,'Iris-virginica':1,'Iris-setosa':2})
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        2
# 1           4.9          3.0           1.4          0.2        2
# 2           4.7          3.2           1.3          0.2        2
# 3           4.6          3.1           1.5          0.2        2
# 4           5.0          3.6           1.4          0.2        2

# %% [markdown]
# # Data Visualization

# %%
col = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
colors = ['blue', 'red', 'green', 'yellow']
plt.figure(figsize=(15,3))
for i in range (4):
    plt.subplot(1,4,i+1)
    sns.violinplot(df[col[i]], color=colors[i])
plt.show()

# %% [markdown]
# The sepal_length values are in range of 5 to 7.
# The sepal_width values are largely concentrated around 3.
# The petal_length values are concentrated in between 1 to 2 and 4 to 6.
# The petal_width values are concentrated in between 0 to 0.5 and 1 to 2.5. as shown in the visualization

# %%
plt.figure(figsize=(3,3))
df['species'].value_counts().plot(kind = 'pie', autopct='%1.1f%%')
plt.legend(['Iris-versicolor','Iris-virginica','Iris-setosa'], bbox_to_anchor = (1,1))
plt.show()

# %% [markdown]
# The Maximum flowers we have are of versicolor species.

# %%
plt.figure(figsize=(4,3))
sns.heatmap(df.corr(), annot=True, cmap = 'twilight')
plt.show()

# %%
sns.pairplot(df, hue='species', palette = 'prism')
plt.show()

# %% [markdown]
# Above pairplot gives bivariate analysis. Petal length and petal width have linear relation.

# %% [markdown]
# # Building a ML model :

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['species'] = le.fit_transform(df['species'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        2
# 1           4.9          3.0           1.4          0.2        2
# 2           4.7          3.2           1.3          0.2        2
# 3           4.6          3.1           1.5          0.2        2
# 4           5.0          3.6           1.4          0.2        2

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
# train - 70
# test - 30
X = df.drop(columns=['species'])
Y = df['species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %%
# logistic regression 
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# model training
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  95.55555555555556

# %%
# knn - k-nearest neighbours
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  100.0

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  91.11111111111111
